# %%
import torch
import torch.nn as nn

# %%
out = torch.load('out_veremi/test-packed.pt')

# %%
padded = nn.utils.rnn.pad_packed_sequence(out)

# %%
padded[0][:, -1]
# Out:
# tensor([[ 9.8863e+02,  9.1430e+02, -1.0825e+01, -7.7537e+00, -4.4172e-02,
#          -3.1608e-02, -9.3052e-01, -3.6625e-01,  8.1575e+02,  7.5940e+02,
#           8.8547e+00, -1.0120e+01,  5.0250e-02, -5.5360e-02,  6.5530e-01,
#          -7.5537e-01,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00],
#         [ 0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
#           0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,  0.0000e+00,
# ...
